# %%
import pandas as pd

# %%
df = pd.read_excel("data/problem_statements.xlsx", sheet_name="Worksheet")

# %%
print(df)
# Out:
#           ID                                              Title  \
# 0    SIH1525  Development of software application for analys...
# 1    SIH1524  Domain Name Server (DNS) Filtering Service usi...
# 2    SIH1523            Quantum Secure Email Client Application
# 3    SIH1522  Development of UT (user terminal) to UT Voice,...
# 4    SIH1521  Development of Explainable AI (XAI) based mode...
# ..       ...                                                ...
# 229  SIH1282  Tech-Driven Solutions for Undertrial Prisoners...
# 230  SIH1281  Development of gamified platform on Children's...
# 231  SIH1280  Development of e-Portal for facilitating Case ...
# 232  SIH1279  Development of software for streamlining the l...
# 233  SIH1278  International Comparative System to Launch Int...
#
#     technology_bucket  category  \
# 0    Space Technology  Software
# 1    Space Technology  Software
# 2    Space Technology  Software
# 3    Space Technology  Software
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Title', 'technology_bucket', 'category', 'description',
#        'organization'],
#       dtype='object')

# %%
df["category"].unique()
# Out:
# array(['Software', 'Hardware'], dtype=object)

# %%
print(df['technology_bucket'].unique())
